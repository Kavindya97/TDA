# %%
pip install gudhi
# Out:
# Requirement already satisfied: gudhi in c:\users\kavindya\anaconda3\lib\site-packages (3.4.1.post1)
# Requirement already satisfied: numpy>=1.9 in c:\users\kavindya\anaconda3\lib\site-packages (from gudhi) (1.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fermat
# Out:
# Requirement already satisfied: fermat in c:\users\kavindya\anaconda3\lib\site-packages (0.2.5)
# Requirement already satisfied: scikit-learn in c:\users\kavindya\anaconda3\lib\site-packages (from fermat) (0.24.1)
# Requirement already satisfied: scipy in c:\users\kavindya\anaconda3\lib\site-packages (from fermat) (1.6.2)
# Requirement already satisfied: numpy in c:\users\kavindya\anaconda3\lib\site-packages (from fermat) (1.20.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\kavindya\anaconda3\lib\site-packages (from scikit-learn->fermat) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kavindya\anaconda3\lib\site-packages (from scikit-learn->fermat) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from src.distance        import *
from src.datasets        import *
from mpl_toolkits        import mplot3d
from ripser              import Rips
from src.DTM_filtrations import *
import matplotlib.colors as colors

# %%
sample = np.loadtxt('data/data.txt')
out = np.loadtxt('data/out.txt')
data = np.concatenate((sample, out))

# %%
cmap = plt.get_cmap('Blues')
new_cmap = truncate_colormap(cmap, 0.4, 1)

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
ax.scatter(sample[:,0], sample[:,1], sample[:,2], s=25, alpha=0.3, c=sample[:,2], cmap=new_cmap)
ax.scatter(out[:,0], out[:,1], out[:,2], s=25, alpha=1, color='red')
ax.view_init(45,45)
plt.show()

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
ax.scatter(sample[:,0], sample[:,1], sample[:,2], s=35, alpha=0.3,  c=sample[:,2], cmap=new_cmap)
ax.scatter(out[:,0], out[:,1], out[:,2], s=35, alpha=1, color='red')
ax.view_init(85,90)
plt.show()

# %% [markdown]
# __Presistance Diagram

# %% [markdown]
# We compare the output of teh computation of persistent homology for different choices of distance, and test its sensitivity to outliers.

# %% [markdown]
# **Euclidean Distance

# %%
rips = Rips()
dgms = rips.fit_transform(sample)
rips.plot(dgms, lifetime=True)
plt.title('Euclidean Distance (without outliers)');
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
rips = Rips()
dgms = rips.fit_transform(data)
rips.plot(dgms, lifetime=True)
plt.title('Euclidean Distance (with outliers)');
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# **K-NN distance

# %%
rips = Rips()
matrix = compute_kNN_distance(sample, 10)
dgms = rips.fit_transform(matrix, distance_matrix=True)
rips.plot(dgms, lifetime=True)

plt.savefig('k-NN distance (without outliers).png', dpi=300, bbox_inches='tight')
plt.title('k-NN distance (without outliers)');
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8ae1d72482f8> in <module>
#       1 rips = Rips()
# ----> 2 matrix = compute_kNN_distance(sample, 10)
#       3 dgms = rips.fit_transform(matrix, distance_matrix=True)
#       4 rips.plot(dgms, lifetime=True)
#       5
#
# ~\Documents\Condapython\src\distance.py in compute_kNN_distance(data, k)
#      49     distances = distance_matrix(data,data)
#      50
# ---> 51     # Initialize the model
#      52     f_aprox_D = Fermat(1, path_method='D', k=k)
#      53
#
# NameError: name 'Fermat' is not defined

# %%
rips = Rips()
matrix = compute_kNN_distance(data, 10)
dgms = rips.fit_transform(matrix, distance_matrix=True)
rips.plot(dgms, lifetime=True)
plt.title('k-NN distance (with outliers)');
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %% [markdown]
# **DTM

# %%
m = 0.01                   
DTM_values = DTM(data,data,m)             

# plot of the DTM
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.scatter(data[:,0], data[:,1], data[:,2], c=DTM_values, s = 10)
ax.set_title('Values of the DTM on X with parameter m='+str(m))
# Out:
# Text(0.5, 0.92, 'Values of the DTM on X with parameter m=0.01')

# %%
m = 0.01                   
DTM_values = DTM(data,data,m)             

# plot of the DTM
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.scatter(data[:,0], data[:,1], data[:,2], c=DTM_values, s = 10)
ax.set_title('Values of the DTM on X with parameter m='+str(m))
# Out:
# Text(0.5, 0.92, 'Values of the DTM on X with parameter m=0.01')

# %%
def AlphaDTMFiltration(X, m, p, dimension_max =2, filtration_max = np.inf):
    '''
    /!\ this is a heuristic method, that speeds-up the computation.
    It computes the DTM-filtration seen as a subset of the Delaunay filtration.
    
    Input:
        X (np.array): size Nxn, representing N points in R^n.
        m (float): parameter of the DTM, in [0,1). 
        p (float): parameter of the DTM-filtration, in [0, +inf) or np.inf.
        dimension_max (int, optional): maximal dimension to expand the complex.
        filtration_max (float, optional): maximal filtration value of the filtration.
    
    Output:
        st (gudhi.SimplexTree): the alpha-DTM filtration.
    '''
    N_tot = X.shape[0]     
    alpha_complex = gudhi.AlphaComplex(points=X)
    st_alpha = alpha_complex.create_simplex_tree()    
    Y = np.array([alpha_complex.get_point(i) for i in range(N_tot)])
    distances = euclidean_distances(Y)             #computes the pairwise distances
    DTM_values = DTM(X,Y,m)                        #/!\ in 3D, gudhi.AlphaComplex may change the ordering of the points
    
    st = gudhi.SimplexTree()                       #creates an empty simplex tree
    for simplex in st_alpha.get_skeleton(2):       #adds vertices with corresponding filtration value
        if len(simplex[0])==1:
            i = simplex[0][0]
            st.insert([i], filtration  = DTM_values[i])
        if len(simplex[0])==2:                     #adds edges with corresponding filtration value
            i = simplex[0][0]
            j = simplex[0][1]
            value = WeightedRipsFiltrationValue(p, DTM_values[i], DTM_values[j], distances[i][j])
            st.insert([i,j], filtration  = value)
    st.expansion(dimension_max)                    #expands the complex
    result_str = 'Alpha Weighted Rips Complex is of dimension ' + repr(st.dimension()) + ' - ' + \
        repr(st.num_simplices()) + ' simplices - ' + \
        repr(st.num_vertices()) + ' vertices.' +\
        ' Filtration maximal value is ' + str(filtration_max) + '.'
    print(result_str)
    return st

# %%
p = 2
dimension_max = 2

# compute the persistence diagram
simplex_tree_DTM_alpha = AlphaDTMFiltration(sample, m, p, dimension_max)
diagram_DTM_alpha = simplex_tree_DTM_alpha.persistence()    

# plot the persistence diagram
rips = Rips()
rips.plot(gudhi_to_ripser(diagram_DTM_alpha), lifetime = True)
plt.title('DTM-filtration (without outliers)');
# Out:
# Alpha Weighted Rips Complex is of dimension 2 - 116473 simplices - 4829 vertices. Filtration maximal value is inf.
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
simplex_tree_DTM_alpha = AlphaDTMFiltration(data, m, p, dimension_max)
diagram_DTM_alpha = simplex_tree_DTM_alpha.persistence()    

# plot the persistence diagram
rips = Rips()
rips.plot(gudhi_to_ripser(diagram_DTM_alpha), lifetime = True)
plt.title('DTM-filtration (with outliers)');
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-3cebcf6eafa8> in <module>
# ----> 1 simplex_tree_DTM_alpha = AlphaDTMFiltration(data, m, p, dimension_max)
#       2 diagram_DTM_alpha = simplex_tree_DTM_alpha.persistence()
#       3
#       4 # plot the persistence diagram
#       5 rips = Rips()
#
# <ipython-input-13-58a98a50392c> in AlphaDTMFiltration(X, m, p, dimension_max, filtration_max)
#      17     alpha_complex = gudhi.AlphaComplex(points=X)
#      18     st_alpha = alpha_complex.create_simplex_tree()
# ---> 19     Y = np.array([alpha_complex.get_point(i) for i in range(N_tot)])
#      20     distances = euclidean_distances(Y)             #computes the pairwise distances
#      21     DTM_values = DTM(X,Y,m)                        #/!\ in 3D, gudhi.AlphaComplex may change the ordering of the points
#
# <ipython-input-13-58a98a50392c> in <listcomp>(.0)
#      17     alpha_complex = gudhi.AlphaComplex(points=X)
#      18     st_alpha = alpha_complex.create_simplex_tree()
# ---> 19     Y = np.array([alpha_complex.get_point(i) for i in range(N_tot)])
#      20     distances = euclidean_distances(Y)             #computes the pairwise distances
#      21     DTM_values = DTM(X,Y,m)                        #/!\ in 3D, gudhi.AlphaComplex may change the ordering of the points
#
# alpha_complex.pyx in gudhi.alpha_complex.AlphaComplex.get_point()
#
# IndexError: invalid vector<T> subscript

# %% [markdown]
# **Fermat Distance

# %%
dgms = Fermat_dgm(sample, p=3, rescaled=False, title = 'Fermat distance (without outliers)')
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
dgms = Fermat_dgm(data, p=3, rescaled=False, title = 'Fermat distance (with outliers)')
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
rips.plot([dgms[0][:0], dgms[1]], lifetime=True, title='Fermat distance with outliers ($H_1$ only)')
plt.legend(['', '', '$H_1$']);

# %%
data1 = np.loadtxt('data/my_array.txt')
#data generated with the function eyeglasses(2000, 0, 'normal', 0.1)
#you can also generate different samples of the eyeglasses dataset with the function eyeglasses(n_obs, n_out, type_noise, var)

cmap = plt.get_cmap('viridis')
new_cmap = truncate_colormap(cmap, minval=0.1, maxval=0.9, n=100)

' Compute the DTM on the point cloud' 
m = 0.01      
DTM_values = DTM(data,data,m) 

# plot of the DTM
fig = plt.figure(figsize = (8,4))
plot=plt.scatter(data[:,0], data[:,1], c=DTM_values, s = 10, alpha = 0.8, cmap = new_cmap)
plt.xticks([])
plt.yticks([])
plt.axis([-3,3, -1.5, 1.5])
plt.title('Noisy sample', fontsize=15)
plt.show()

# %%
rips = Rips()
dgms = rips.fit_transform(data1)
rips.plot(dgms, lifetime=True)
plt.title('Euclidean distance');
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9,9))
for i, n in enumerate([0.0, 0.05, 0.1, 0.15, 0.2, 0.3, 0.4, 0.6, 0.8]):
    plt.subplot(331+i)

    #ds_clean = tadasets.dsphere(d=1, n=100, noise=0.0)
    dgm_clean = ripser.ripser(data1)['dgms'][1]

    #ds = tadasets.dsphere(d=1, n=100, noise=n)
    dgm = ripser.ripser(data1)['dgms'][1]

    d, matching = persim.bottleneck(
        dgm_clean,
        dgm,
        matching=True
    )

    persim.bottleneck_matching(dgm_clean, dgm, matching, labels=['Clean $H_1$', 'Noisy $H_1$'])

    plt.title("Noise:{} Distance:{:.3f}".format(n, d))

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-52172500fc56> in <module>
#       4
#       5     #ds_clean = tadasets.dsphere(d=1, n=100, noise=0.0)
# ----> 6     dgm_clean = ripser.ripser(data1)['dgms'][1]
#       7
#       8     #ds = tadasets.dsphere(d=1, n=100, noise=n)
#
# NameError: name 'ripser' is not defined
